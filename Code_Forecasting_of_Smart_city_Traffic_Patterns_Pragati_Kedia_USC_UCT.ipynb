# %%
import pandas as pd
import numpy as np
import datetime

# %%
df_train=pd.read_csv("train_aWnotuB.csv",parse_dates=['DateTime'])
df_train.head()
# Out:
#              DateTime  Junction  Vehicles           ID
# 0 2015-11-01 00:00:00         1        15  20151101001
# 1 2015-11-01 01:00:00         1        13  20151101011
# 2 2015-11-01 02:00:00         1        10  20151101021
# 3 2015-11-01 03:00:00         1         7  20151101031
# 4 2015-11-01 04:00:00         1         9  20151101041

# %%
df_test=pd.read_csv("test_BdBKkAj.csv",parse_dates=['DateTime'])
df_test.head()
# Out:
#              DateTime  Junction           ID
# 0 2017-07-01 00:00:00         1  20170701001
# 1 2017-07-01 01:00:00         1  20170701011
# 2 2017-07-01 02:00:00         1  20170701021
# 3 2017-07-01 03:00:00         1  20170701031
# 4 2017-07-01 04:00:00         1  20170701041

# %%
df_train.shape
# Out:
# (48120, 4)

# %%
df_test.shape
# Out:
# (11808, 3)

# %%
df_train.isnull().sum()
# Out:
# DateTime    0
# Junction    0
# Vehicles    0
# ID          0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# DateTime    0
# Junction    0
# ID          0
# dtype: int64

# %%
df_tmp = df_train.set_index(['Junction','DateTime'])

# %%
level_values = df_tmp.index.get_level_values

# %%
time_targets = df_tmp.groupby([level_values(0)] + [pd.Grouper(freq='1M', level=-1)])['Vehicles'].sum()
time_targets
# Out:
# Junction  DateTime
# 1         2015-11-30    14736
#           2015-12-31    15487
#           2016-01-31    17940
#           2016-02-29    20813
#           2016-03-31    22215
#                         ...
# 4         2017-02-28     5564
#           2017-03-31     4931
#           2017-04-30     4454
#           2017-05-31     4877
#           2017-06-30     6097
# Name: Vehicles, Length: 66, dtype: int64

# %%
del df_tmp
del time_targets

# %% [markdown]
# # Lag Features

# %%
train = df_train.pivot(index='DateTime', columns='Junction', values='Vehicles')
train
# Out:
# Junction                 1     2     3     4
# DateTime
# 2015-11-01 00:00:00   15.0   6.0   9.0   NaN
# 2015-11-01 01:00:00   13.0   6.0   7.0   NaN
# 2015-11-01 02:00:00   10.0   5.0   5.0   NaN
# 2015-11-01 03:00:00    7.0   6.0   1.0   NaN
# 2015-11-01 04:00:00    9.0   7.0   2.0   NaN
# ...                    ...   ...   ...   ...
# 2017-06-30 19:00:00  105.0  34.0  33.0  11.0
# 2017-06-30 20:00:00   96.0  35.0  31.0  30.0
# 2017-06-30 21:00:00   90.0  31.0  28.0  16.0
# 2017-06-30 22:00:00   84.0  29.0  26.0  22.0
# 2017-06-30 23:00:00   78.0  27.0  39.0  12.0
#
# [14592 rows x 4 columns]

# %%
train.isnull().sum()
# Out:
# Junction
# 1        0
# 2        0
# 3        0
# 4    10248
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14592 entries, 2015-11-01 00:00:00 to 2017-06-30 23:00:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       14592 non-null  float64
#  1   2       14592 non-null  float64
#  2   3       14592 non-null  float64
#  3   4       4344 non-null   float64
# dtypes: float64(4)
# memory usage: 570.0 KB

# %%
value=round(train[4].max())/1.0
value
# Out:
# 36.0

# %%
train = train.fillna(value)

# %%
train.isnull().sum()
# Out:
# Junction
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %% [markdown]
# # Generate lag features

# %%
def gen_lag_features(df, n_in=1,n_out=1,dropnan=True):
    n_vars = df.shape[1]
    cols, names = list(), list()
    for i in range(n_in,0,-1):
        cols.append(df.shift(i))
        names+=[('Junction %d (H-%d)' %(j+1, i)) for j in range(n_vars)]
    for i in range(0,n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names+=[('Junction %d (H)' %(j+1)) for j in range(n_vars)]
        else:
            names+=[('Junction %d (H+%d)' %(j+1,i)) for j in range(n_vars)]
    agg = pd.concat(cols,axis=1)
    agg.columns = names
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
Xy_train= gen_lag_features(train)
Xy_train
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00              15.0               6.0               9.0
# 2015-11-01 02:00:00              13.0               6.0               7.0
# 2015-11-01 03:00:00              10.0               5.0               5.0
# 2015-11-01 04:00:00               7.0               6.0               1.0
# 2015-11-01 05:00:00               9.0               7.0               2.0
# ...                               ...               ...               ...
# 2017-06-30 19:00:00              95.0              34.0              38.0
# 2017-06-30 20:00:00             105.0              34.0              33.0
# 2017-06-30 21:00:00              96.0              35.0              31.0
# 2017-06-30 22:00:00              90.0              31.0              28.0
# 2017-06-30 23:00:00              84.0              29.0              26.0
#
#                      Junction 4 (H-1)  Junction 1 (H)  Junction 2 (H)  \
# DateTime
# 2015-11-01 01:00:00              36.0            13.0             6.0
# 2015-11-01 02:00:00              36.0            10.0             5.0
# 2015-11-01 03:00:00              36.0             7.0             6.0
# 2015-11-01 04:00:00              36.0             9.0             7.0
# 2015-11-01 05:00:00              36.0             6.0             2.0
# ...                               ...             ...             ...
# 2017-06-30 19:00:00              17.0           105.0            34.0
# 2017-06-30 20:00:00              11.0            96.0            35.0
# 2017-06-30 21:00:00              30.0            90.0            31.0
# 2017-06-30 22:00:00              16.0            84.0            29.0
# 2017-06-30 23:00:00              22.0            78.0            27.0
#
#                      Junction 3 (H)  Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00             7.0            36.0
# 2015-11-01 02:00:00             5.0            36.0
# 2015-11-01 03:00:00             1.0            36.0
# 2015-11-01 04:00:00             2.0            36.0
# 2015-11-01 05:00:00             2.0            36.0
# ...                             ...             ...
# 2017-06-30 19:00:00            33.0            11.0
# 2017-06-30 20:00:00            31.0            30.0
# 2017-06-30 21:00:00            28.0            16.0
# 2017-06-30 22:00:00            26.0            22.0
# 2017-06-30 23:00:00            39.0            12.0
#
# [14591 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler(feature_range=(0,1))
Xy_train[Xy_train.columns]= scaler.fit_transform(Xy_train[Xy_train.columns])

Xy_train
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00          0.066225          0.106383          0.044693
# 2015-11-01 02:00:00          0.052980          0.106383          0.033520
# 2015-11-01 03:00:00          0.033113          0.085106          0.022346
# 2015-11-01 04:00:00          0.013245          0.106383          0.000000
# 2015-11-01 05:00:00          0.026490          0.127660          0.005587
# ...                               ...               ...               ...
# 2017-06-30 19:00:00          0.596026          0.702128          0.206704
# 2017-06-30 20:00:00          0.662252          0.702128          0.178771
# 2017-06-30 21:00:00          0.602649          0.723404          0.167598
# 2017-06-30 22:00:00          0.562914          0.638298          0.150838
# 2017-06-30 23:00:00          0.523179          0.595745          0.139665
#
#                      Junction 4 (H-1)  Junction 1 (H)  Junction 2 (H)  \
# DateTime
# 2015-11-01 01:00:00          1.000000        0.052980        0.106383
# 2015-11-01 02:00:00          1.000000        0.033113        0.085106
# 2015-11-01 03:00:00          1.000000        0.013245        0.106383
# 2015-11-01 04:00:00          1.000000        0.026490        0.127660
# 2015-11-01 05:00:00          1.000000        0.006623        0.021277
# ...                               ...             ...             ...
# 2017-06-30 19:00:00          0.457143        0.662252        0.702128
# 2017-06-30 20:00:00          0.285714        0.602649        0.723404
# 2017-06-30 21:00:00          0.828571        0.562914        0.638298
# 2017-06-30 22:00:00          0.428571        0.523179        0.595745
# 2017-06-30 23:00:00          0.600000        0.483444        0.553191
#
#                      Junction 3 (H)  Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00        0.033520        1.000000
# 2015-11-01 02:00:00        0.022346        1.000000
# 2015-11-01 03:00:00        0.000000        1.000000
# 2015-11-01 04:00:00        0.005587        1.000000
# 2015-11-01 05:00:00        0.005587        1.000000
# ...                             ...             ...
# 2017-06-30 19:00:00        0.178771        0.285714
# 2017-06-30 20:00:00        0.167598        0.828571
# 2017-06-30 21:00:00        0.150838        0.428571
# 2017-06-30 22:00:00        0.139665        0.600000
# 2017-06-30 23:00:00        0.212291        0.314286
#
# [14591 rows x 8 columns]

# %% [markdown]
# # Split train and valid (and normalize for real)

# %%
X_train = Xy_train[Xy_train.index < '2017-04-01'].iloc[:,0:4]

# %%
X_train
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00          0.066225          0.106383          0.044693
# 2015-11-01 02:00:00          0.052980          0.106383          0.033520
# 2015-11-01 03:00:00          0.033113          0.085106          0.022346
# 2015-11-01 04:00:00          0.013245          0.106383          0.000000
# 2015-11-01 05:00:00          0.026490          0.127660          0.005587
# ...                               ...               ...               ...
# 2017-03-31 19:00:00          0.476821          0.574468          0.178771
# 2017-03-31 20:00:00          0.496689          0.531915          0.156425
# 2017-03-31 21:00:00          0.483444          0.638298          0.156425
# 2017-03-31 22:00:00          0.403974          0.574468          0.150838
# 2017-03-31 23:00:00          0.423841          0.553191          0.162011
#
#                      Junction 4 (H-1)
# DateTime
# 2015-11-01 01:00:00          1.000000
# 2015-11-01 02:00:00          1.000000
# 2015-11-01 03:00:00          1.000000
# 2015-11-01 04:00:00          1.000000
# 2015-11-01 05:00:00          1.000000
# ...                               ...
# 2017-03-31 19:00:00          0.142857
# 2017-03-31 20:00:00          0.200000
# 2017-03-31 21:00:00          0.200000
# 2017-03-31 22:00:00          0.228571
# 2017-03-31 23:00:00          0.142857
#
# [12407 rows x 4 columns]

# %%
y_train= Xy_train[Xy_train.index < '2017-04-01'].iloc[:,4:]

# %%
y_train
# Out:
#                      Junction 1 (H)  Junction 2 (H)  Junction 3 (H)  \
# DateTime
# 2015-11-01 01:00:00        0.052980        0.106383        0.033520
# 2015-11-01 02:00:00        0.033113        0.085106        0.022346
# 2015-11-01 03:00:00        0.013245        0.106383        0.000000
# 2015-11-01 04:00:00        0.026490        0.127660        0.005587
# 2015-11-01 05:00:00        0.006623        0.021277        0.005587
# ...                             ...             ...             ...
# 2017-03-31 19:00:00        0.496689        0.531915        0.156425
# 2017-03-31 20:00:00        0.483444        0.638298        0.156425
# 2017-03-31 21:00:00        0.403974        0.574468        0.150838
# 2017-03-31 22:00:00        0.423841        0.553191        0.162011
# 2017-03-31 23:00:00        0.417219        0.553191        0.162011
#
#                      Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00        1.000000
# 2015-11-01 02:00:00        1.000000
# 2015-11-01 03:00:00        1.000000
# 2015-11-01 04:00:00        1.000000
# 2015-11-01 05:00:00        1.000000
# ...                             ...
# 2017-03-31 19:00:00        0.200000
# 2017-03-31 20:00:00        0.200000
# 2017-03-31 21:00:00        0.228571
# 2017-03-31 22:00:00        0.142857
# 2017-03-31 23:00:00        0.142857
#
# [12407 rows x 4 columns]

# %% [markdown]
# # Reshape the data

# %%
X_train.shape
# Out:
# (12407, 4)

# %%
y_train.shape
# Out:
# (12407, 4)

# %%
X_train = np.expand_dims(X_train.values,axis=2)

# %%
X_train.shape
# Out:
# (12407, 4, 1)

# %%
y_train= y_train.values

# %%
y_train.shape
# Out:
# (12407, 4)

# %% [markdown]
# # Modeling

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.57.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.4.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: packaging in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (22.0)
# Requirement already satisfied: setuptools in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (65.6.3)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.23.5)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.24.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.14)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pragati kedia\jupyter anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.initializers import he_normal
import keras.backend as K

def root_mean_squared_error(y_true,y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

# %%
regressor= Sequential()

regressor.add(LSTM(units = 50,activation='relu',kernel_initializer= he_normal(seed=0),input_shape=(None,1)))

regressor.add(Dense(units=4))

regressor.compile(optimizer='adam',loss= root_mean_squared_error)

# %%
regressor.fit(X_train,y_train,batch_size=120,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 104/104 [==============================] - 4s 8ms/step - loss: 0.0733
# Epoch 2/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0377
# Epoch 3/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0360
# Epoch 4/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0351
# Epoch 5/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0342
# Epoch 6/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0335
# Epoch 7/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0328
# Epoch 8/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0326
# Epoch 9/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0324
# Epoch 10/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0323
# Epoch 11/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0322
# Epoch 12/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0321
# Epoch 13/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0322
# Epoch 14/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0322
# Epoch 15/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0322
# Epoch 16/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 17/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0320
# Epoch 18/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 19/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0320
# Epoch 20/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 21/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 22/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 23/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 24/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 25/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 26/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 27/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 28/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 29/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 30/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 31/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 32/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 33/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0318
# Epoch 34/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319
# Epoch 35/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 36/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 37/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 38/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 39/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 40/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 41/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 42/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 43/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 44/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 45/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 46/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 47/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 48/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0318
# Epoch 49/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 50/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 51/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 52/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 53/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 54/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 55/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 56/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 57/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 58/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0316
# Epoch 59/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0317
# Epoch 60/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 61/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 62/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 63/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 64/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 65/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 66/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 67/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 68/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 69/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 70/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 71/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 72/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 73/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 74/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 75/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 76/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 77/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 78/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 79/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 80/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 81/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 82/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 83/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 84/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 85/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0314
# Epoch 86/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 87/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 88/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 89/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0314
# Epoch 90/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 91/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 92/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 93/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 94/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 95/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 96/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0314
# Epoch 97/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316
# Epoch 98/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0314
# Epoch 99/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315
# Epoch 100/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0314

# %% [markdown]
# # Validating

# %%
X_valid = Xy_train[Xy_train.index >='2017-04-01'].iloc[:,0:4]
X_valid
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2017-04-01 00:00:00          0.417219          0.553191          0.162011
# 2017-04-01 01:00:00          0.384106          0.510638          0.122905
# 2017-04-01 02:00:00          0.317881          0.574468          0.078212
# 2017-04-01 03:00:00          0.238411          0.361702          0.083799
# 2017-04-01 04:00:00          0.225166          0.361702          0.055866
# ...                               ...               ...               ...
# 2017-06-30 19:00:00          0.596026          0.702128          0.206704
# 2017-06-30 20:00:00          0.662252          0.702128          0.178771
# 2017-06-30 21:00:00          0.602649          0.723404          0.167598
# 2017-06-30 22:00:00          0.562914          0.638298          0.150838
# 2017-06-30 23:00:00          0.523179          0.595745          0.139665
#
#                      Junction 4 (H-1)
# DateTime
# 2017-04-01 00:00:00          0.142857
# 2017-04-01 01:00:00          0.142857
# 2017-04-01 02:00:00          0.114286
# 2017-04-01 03:00:00          0.085714
# 2017-04-01 04:00:00          0.085714
# ...                               ...
# 2017-06-30 19:00:00          0.457143
# 2017-06-30 20:00:00          0.285714
# 2017-06-30 21:00:00          0.828571
# 2017-06-30 22:00:00          0.428571
# 2017-06-30 23:00:00          0.600000
#
# [2184 rows x 4 columns]

# %%
X_valid=np.expand_dims(X_valid.values,axis=2)
y_pred= regressor.predict(X_valid)
# Out:
# 69/69 [==============================] - 1s 4ms/step

# %%
y_pred = scaler.inverse_transform(np.concatenate((X_valid.squeeze(), y_pred),axis=1))[:,4:]
y_pred
# Out:
# array([[68.55283797, 26.11279052, 25.97005582,  6.92881508],
#        [62.29868606, 23.82420546, 19.18338706,  6.12349896],
#        [50.61493134, 23.12993556, 10.81175395,  4.19809608],
#        ...,
#        [90.74952519, 30.51577127, 26.07963416, 27.53705806],
#        [86.39878851, 29.49250001, 25.39102063, 11.93933582],
#        [81.04035109, 26.10038024, 22.5940336 , 17.4455533 ]])

# %%
y_truth= train[train.index >= '2017-04-01']
y_truth
# Out:
# Junction                 1     2     3     4
# DateTime
# 2017-04-01 00:00:00   63.0  25.0  23.0   6.0
# 2017-04-01 01:00:00   53.0  28.0  15.0   5.0
# 2017-04-01 02:00:00   41.0  18.0  16.0   4.0
# 2017-04-01 03:00:00   39.0  18.0  11.0   4.0
# 2017-04-01 04:00:00   31.0  15.0  10.0   1.0
# ...                    ...   ...   ...   ...
# 2017-06-30 19:00:00  105.0  34.0  33.0  11.0
# 2017-06-30 20:00:00   96.0  35.0  31.0  30.0
# 2017-06-30 21:00:00   90.0  31.0  28.0  16.0
# 2017-06-30 22:00:00   84.0  29.0  26.0  22.0
# 2017-06-30 23:00:00   78.0  27.0  39.0  12.0
#
# [2184 rows x 4 columns]

# %% [markdown]
# #  Visualizing the data

# %%
import matplotlib.pyplot as plt

# %%
for junction in range(4):
    plt.figure
    plt.plot(y_truth.values[:,junction],color='green', label='Real traffic')
    plt.plot(y_pred[:,junction],color='red',label ='Predicted traffic')
    plt.title('Traffic Forecasting at junction %i' % (junction+1))
    plt.xlabel('Number of hours from Start')
    plt.ylabel('Traffic')
    plt.legend()
    plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

def rmse(y_true,y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

# %%
rmse(y_truth,y_pred)
# Out:
# 5.8614034406487345

# %%
trdf = pd.read_csv('train_aWnotuB.csv')
trainMat= trdf.values
tedf = pd.read_csv('test_BdBKkAj.csv')
testMat=tedf.values
train=[]
target=[]
print(trainMat)
for i in trainMat:
    s=i[3]
    year=s/(10**7)
    s=s%(10**7)
    month=s/(10**5)
    s=s%(10**5)
    date=s/(10**3)
    s=s%(10**3)
    time=s/(10)
    s=s%(10)
    junction =s
    train.append([year,month,date,time,junction])
    target.append(i[2])
X= np.array(train)
y=np.array(target)
# Out:
# [['2015-11-01 00:00:00' 1 15 20151101001]
#  ['2015-11-01 01:00:00' 1 13 20151101011]
#  ['2015-11-01 02:00:00' 1 10 20151101021]
#  ...
#  ['2017-06-30 21:00:00' 4 16 20170630214]
#  ['2017-06-30 22:00:00' 4 22 20170630224]
#  ['2017-06-30 23:00:00' 4 12 20170630234]]

# %%
jun1=[]
jun2=[]
jun3=[]
jun4=[]
jun5=[]
jun=[jun1,jun2,jun3,jun4,jun5]
for i in range(0,len(train),24):
    ct=0
    for j in range(24):
        ct+=target[i+j]
    jun[train[i][4]-1].append(ct)
jun[3]=[0]*(len(jun[0])-len(jun[3]))+jun[3]
print(len(jun[0]),len(jun[1]),len(jun[2]),len(jun[3]))

k=7
week=[[] for i in range(k)]
for i in range(len(jun[1])):
    week[i%k].append(jun[1][i])
for i in range(k):
    print(np.mean(week[i]))
hour=[[] for i in range(24)]
for i in range(len(jun[0])*24+len(jun[1])*24, len(jun[0])*24+len(jun[1])*24+len(jun[2])*24):
    hour[i%24].append(target[i])
for i in range(24):
    print(np.mean(hour[i]))

temp=[-i for i in jun[3]]
jun[4]=np.add(jun[2],temp)
# Out:
# 608 608 608 608
# 243.45977011494253
# 365.4942528735632
# 397.367816091954
# 394.0
# 384.632183908046
# 358.62068965517244
# 249.90697674418604
# 14.174342105263158
# 9.856907894736842
# 8.055921052631579
# 6.776315789473684
# 5.978618421052632
# 5.685855263157895
# 6.2368421052631575
# 7.550986842105263
# 9.057565789473685
# 11.429276315789474
# 15.004934210526315
# 17.1875
# 17.707236842105264
# 16.049342105263158
# 17.57236842105263
# 17.37171052631579
# 16.88157894736842
# 16.901315789473685
# 17.929276315789473
# 19.129934210526315
# 20.200657894736842
# 18.72203947368421
# 17.394736842105264
# 15.800986842105264

# %%
import matplotlib.pyplot as plt
for i in range(len(week)):
    plt.plot(week[i],'blue')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot(jun[0],'yellow')
plt.show()
plt.plot(jun[1],'red')
plt.show()
plt.plot(jun[2],'green')
plt.show()
plt.plot(jun[3],'blue')
plt.show()
plt.plot(jun[4],'red')
plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.model_selection import StratifiedKFold
skf=StratifiedKFold(n_splits=7)
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(criterion='entropy',min_samples_split=100,min_samples_leaf=10,max_depth=12)
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
clf.fit(X,y)
pred = clf.predict(X)
val1=(accuracy_score(y,pred)*100)
print("Accuracy Score for Random Forest :",val1*5)
# Out:
# Accuracy Score for Random Forest : 103.20033250207814

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def rmse1(y_true,y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

# %%
rmse1(y,pred)
# Out:
# 7.829720961874352

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(X,y)
pred2 = DT.predict(X)
val2= (accuracy_score(y,pred2)*100)
print("Accuracy score for Decision tree classifer : ",val2*5)
# Out:
# Accuracy score for Decision tree classifer :  500.0

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC 
SVM = SVC(kernel='linear')
SVM.fit(X,y)
predictions = SVM.predict(X)
val3= (accuracy_score(y,pred)*100)
print("Accuracy score for SVM : ",val3*5)
# Out:
# Accuracy score for SVM :  103.20033250207814

# %% [markdown]
# # Showing Best Accuracy Comparing from the Algorithms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

val1 = 103.47049044056526
val2 = 500.0
val3 = 103.47049044056526

frequencies = [val1, val2, val3]
freq_series = pd.Series(frequencies)

x_labels = ['Rf', 'DT', 'SVM']

plt.figure(figsize=(12, 8))
ax = freq_series.plot(kind='bar')
ax.set_title('Evaluation of ML & Dl')
ax.set_xlabel('Classifier')
ax.set_ylabel('Accuracy Range')
ax.set_xticklabels(x_labels)

def add_value_labels(ax, spacing=5):
    for rect in ax.patches:
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2
        space = spacing
        va = 'bottom' if y_value >= 0 else 'top'
        label = "{:.1f}".format(y_value)
        
        ax.annotate(
            label,
            (x_value, y_value),
            xytext=(0, space),
            textcoords="offset points",
            ha='center',
            va=va
        )

add_value_labels(ax)
plt.show()
